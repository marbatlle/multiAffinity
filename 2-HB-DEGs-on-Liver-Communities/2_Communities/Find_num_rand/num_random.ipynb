# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks

data = pd.read_csv('/home/mar/Documents/TFM/GitHub/HB_PublicData/2-HB-DEGs-on-Liver-Communities/2_FindMolTiCommunities/Find_num_rand/until100/dif_num_rand.csv',sep=';',index_col=0)

# %%
data.head()
# Out:
#                     num_communities  avg_community_size
# num_randomizations
# 0                                23              510.00
# 1                                23              510.00
# 5                               178               65.94
# 10                              456               25.74
# 15                              761               15.42

# %%
sns.set_style("whitegrid")
g = sns.relplot(x="num_communities", y="avg_community_size", kind="line", data=data)
g.fig.suptitle('Community numbers vs Average Size')
g.fig.autofmt_xdate()
plt.savefig('comm_num_vs_avg_size.png', bbox_inches='tight')

# %%
data.diff()
# Out:
#                     num_clusters
# num_randomizations
# 0                            NaN
# 1                            0.0
# 5                          155.0
# 10                         278.0
# 15                         305.0
# 20                         282.0
# 40                         902.0
# 60                         715.0
# 80                         549.0
# 100                        437.0
# 120                        367.0
# 140                        330.0
# 160                        278.0
# 180                        249.0
# 200                        194.0
# 250                        473.0
# 300                        388.0
# 400                        567.0
# 600                        824.0
# 800                        516.0
# 1000                       398.0
# 1500                       766.0
# 2000                       528.0
# 3000                       602.0
# 5000                       657.0
# 8000                       405.0
# ...
