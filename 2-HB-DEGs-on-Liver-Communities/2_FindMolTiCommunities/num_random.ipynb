# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.signal import find_peaks

data = pd.read_csv('/home/mar/Documents/TFM/GitHub/HB_PublicData/2-HB-DEGs-on-Liver-Communities/2_FindMolTiCommunities/dif_num_rand.csv',sep=';',index_col=0)

# %%
sns.set_style("whitegrid")
g = sns.relplot(x="num_randomizations", y="num_clusters", kind="line", data=data)
g.fig.suptitle('Visualizing different settings')
g.fig.autofmt_xdate()
plt.savefig('num_randomizations.png', bbox_inches='tight')

# %%
# find plateau: https://stackoverflow.com/questions/53492508/find-plateau-in-numpy-array
